# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\Rasidul\AppData\Roaming\Python\Python313\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Rasidul\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Rasidul\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Rasidul\AppData\Roaming\Python\Python313\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Rasidul\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")

# %%
sns.countplot(x = 'Outcome', data = df)
plt.title("Diabetes Outcome Distribution")
plt.show()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.countplot(x = 'Pregnancies', data = df)
plt.title("Diabetes Outcome Distribution")
plt.show()

# %%
df.hist(figsize=(12, 10), bins= 20)
plt.suptitle("Diabetes Data Distribution")
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
features = df.columns[:-1]
for col in features:
    plt.figure()
    sns.boxplot(x = 'Outcome', y = col, data = df)
    plt.title(f"{col} vs Outcome")
    plt.show()
